# %%
import pandas as pd
df = pd.read_csv('salaries_by_college_major.csv')

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df = df.dropna()
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
df['Starting Median Salary']
# Out:
# 0     46000.0
# 1     57700.0
# 2     42600.0
# 3     36800.0
# 4     41600.0
# 5     35800.0
# 6     38800.0
# 7     43000.0
# 8     63200.0
# 9     42600.0
# 10    53900.0
# 11    38100.0
# 12    61400.0
# 13    55900.0
# 14    53700.0
# 15    35000.0
# 16    35900.0
# 17    50100.0
# 18    34900.0
# 19    60900.0
# 20    38000.0
# 21    37900.0
# 22    47900.0
# 23    39100.0
# 24    41200.0
# 25    43500.0
# 26    35700.0
# 27    38800.0
# 28    39200.0
# 29    37800.0
# 30    57700.0
# 31    49100.0
# 32    36100.0
# 33    40900.0
# 34    35600.0
# 35    49200.0
# 36    40800.0
# 37    45400.0
# 38    57900.0
# 39    35900.0
# 40    54200.0
# 41    39900.0
# 42    39900.0
# 43    74300.0
# 44    50300.0
# 45    40800.0
# 46    35900.0
# 47    34100.0
# 48    36500.0
# 49    34000.0
# 50        NaN
# Name: Starting Median Salary, dtype: float64

# %%
clean_df['Starting Median Salary']
# Out:
# 0     46000.0
# 1     57700.0
# 2     42600.0
# 3     36800.0
# 4     41600.0
# 5     35800.0
# 6     38800.0
# 7     43000.0
# 8     63200.0
# 9     42600.0
# 10    53900.0
# 11    38100.0
# 12    61400.0
# 13    55900.0
# 14    53700.0
# 15    35000.0
# 16    35900.0
# 17    50100.0
# 18    34900.0
# 19    60900.0
# 20    38000.0
# 21    37900.0
# 22    47900.0
# 23    39100.0
# 24    41200.0
# 25    43500.0
# 26    35700.0
# 27    38800.0
# 28    39200.0
# 29    37800.0
# 30    57700.0
# 31    49100.0
# 32    36100.0
# 33    40900.0
# 34    35600.0
# 35    49200.0
# 36    40800.0
# 37    45400.0
# 38    57900.0
# 39    35900.0
# 40    54200.0
# 41    39900.0
# 42    39900.0
# 43    74300.0
# 44    50300.0
# 45    40800.0
# 46    35900.0
# 47    34100.0
# 48    36500.0
# 49    34000.0
# Name: Starting Median Salary, dtype: float64

# %%
clean_df['Starting Median Salary'].loc[43]
# Out:
# 74300.0

# %%
clean_df['Starting Median Salary'][43]
# Out:
# 74300.0

# %%
clean_df['Undergraduate Major'][43]
# Out:
# 'Physician Assistant'

# %%
clean_df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %%
clean_df['Mid-Career Median Salary'].idxmax()
# Out:
# 8

# %%
clean_df.loc[8]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                            63200.0
# Mid-Career Median Salary                         107000.0
# Mid-Career 10th Percentile Salary                 71900.0
# Mid-Career 90th Percentile Salary                194000.0
# Group                                                STEM
# Name: 8, dtype: object

# %%
clean_df['Starting Median Salary'].idxmin()
# Out:
# 49

# %%
clean_df.loc[49]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %%
clean_df.loc[clean_df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
clean_df.insert(1, "Spread", spread_col)
clean_df.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
low_risk = clean_df.sort_values('Spread')

# %%
low_risk[['Undergraduate Major', 'Spread']].head()
# Out:
#            Undergraduate Major   Spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %%
clean_df.columns
# Out:
# Index(['Undergraduate Major', 'Spread', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
highest_potential = clean_df.sort_values('Mid-Career 90th Percentile Salary')
highest_potential.head()
# Out:
#            Undergraduate Major   Spread  Starting Median Salary  \
# 49                     Spanish  65400.0                 34000.0
# 47                    Religion  66700.0                 34100.0
# 40                     Nursing  50700.0                 54200.0
# 41                   Nutrition  65300.0                 39900.0
# 27  Health Care Administration  66400.0                 38800.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 49                   53100.0                            31000.0
# 47                   52000.0                            29700.0
# 40                   67000.0                            47600.0
# 41                   55300.0                            33900.0
# 27                   60600.0                            34600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 49                            96400.0      HASS
# 47                            96400.0      HASS
# ...

# %%
highest_potential.tail()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 44               Physics  122000.0                 50300.0
# 37                  Math  137800.0                 45400.0
# 8   Chemical Engineering  122100.0                 63200.0
# 22               Finance  147800.0                 47900.0
# 17             Economics  159400.0                 50100.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 44                   97300.0                            56000.0
# 37                   92400.0                            45200.0
# 8                   107000.0                            71900.0
# 22                   88300.0                            47200.0
# 17                   98600.0                            50600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 44                           178000.0      STEM
# 37                           183000.0      STEM
# 8                            194000.0      STEM
# ...

# %%
grad_spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Starting Median Salary']
clean_df.insert(2, 'Grad To Mid 90th Spread', grad_spread_col)

# %%
clean_df.sort_values('Grad To Mid 90th Spread')
clean_df.head()
# Out:
#      Undergraduate Major    Spread  Grad To Mid 90th Spread  \
# 0             Accounting  109800.0                 106000.0
# 1  Aerospace Engineering   96700.0                 103300.0
# 2            Agriculture  113700.0                 107400.0
# 3           Anthropology  104200.0                 101200.0
# 4           Architecture   85400.0                  94400.0
#
#    Starting Median Salary  Mid-Career Median Salary  \
# 0                 46000.0                   77100.0
# 1                 57700.0                  101000.0
# 2                 42600.0                   71900.0
# 3                 36800.0                   61500.0
# 4                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# ...

# %%
grad_spread_col.head()
# Out:
# 0    106000.0
# 1    103300.0
# 2    107400.0
# 3    101200.0
# 4     94400.0
# dtype: float64

# %%
grad_diff_sorted = clean_df.sort_values('Grad To Mid 90th Spread')
grad_diff_sorted.head()
# Out:
#            Undergraduate Major   Spread  Grad To Mid 90th Spread  \
# 40                     Nursing  50700.0                  44100.0
# 43         Physician Assistant  57600.0                  49700.0
# 41                   Nutrition  65300.0                  59300.0
# 27  Health Care Administration  66400.0                  62200.0
# 47                    Religion  66700.0                  62300.0
#
#     Starting Median Salary  Mid-Career Median Salary  \
# 40                 54200.0                   67000.0
# 43                 74300.0                   91700.0
# 41                 39900.0                   55300.0
# 27                 38800.0                   60600.0
# 47                 34100.0                   52000.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 40                            47600.0                            98300.0
# 43                            66400.0                           124000.0
# ...

# %%
grad_diff_sorted.tail()
# Out:
#      Undergraduate Major    Spread  Grad To Mid 90th Spread  \
# 8   Chemical Engineering  122100.0                 130800.0
# 36             Marketing  132900.0                 134200.0
# 37                  Math  137800.0                 137600.0
# 22               Finance  147800.0                 147100.0
# 17             Economics  159400.0                 159900.0
#
#     Starting Median Salary  Mid-Career Median Salary  \
# 8                  63200.0                  107000.0
# 36                 40800.0                   79600.0
# 37                 45400.0                   92400.0
# 22                 47900.0                   88300.0
# 17                 50100.0                   98600.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 8                             71900.0                           194000.0
# 36                            42100.0                           175000.0
# ...

# %%
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Spread  Grad To Mid 90th Spread  \
# Group
# Business                   12      12                       12
# HASS                       22      22                       22
# STEM                       16      16                       16
#
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business                      12                        12
# HASS                          22                        22
# STEM                          16                        16
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                                 12                                 12
# HASS                                     22                                 22
# STEM                                     16                                 16

# %%
clean_df.groupby('Group').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %%
clean_df.head()
# Out:
#      Undergraduate Major    Spread  Grad To Mid 90th Spread  \
# 0             Accounting  109800.0                 106000.0
# 1  Aerospace Engineering   96700.0                 103300.0
# 2            Agriculture  113700.0                 107400.0
# 3           Anthropology  104200.0                 101200.0
# 4           Architecture   85400.0                  94400.0
#
#    Starting Median Salary  Mid-Career Median Salary  \
# 0                 46000.0                   77100.0
# 1                 57700.0                  101000.0
# 2                 42600.0                   71900.0
# 3                 36800.0                   61500.0
# 4                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# ...

# %%
clean_df
# Out:
#                      Undergraduate Major    Spread  Grad To Mid 90th Spread  \
# 0                             Accounting  109800.0                 106000.0
# 1                  Aerospace Engineering   96700.0                 103300.0
# 2                            Agriculture  113700.0                 107400.0
# 3                           Anthropology  104200.0                 101200.0
# 4                           Architecture   85400.0                  94400.0
# 5                            Art History   96200.0                  89200.0
# 6                                Biology   98100.0                  96200.0
# 7                    Business Management  108200.0                 104000.0
# 8                   Chemical Engineering  122100.0                 130800.0
# 9                              Chemistry  102700.0                 105400.0
# 10                     Civil Engineering   84600.0                  94100.0
# ...

# %%
salaries_grouped = clean_df.groupby('Group')

# %%
salaries_grouped

# %%
print(salaries_grouped)

# %%
salaries_grouped.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %%
salaries_grouped.head()
# Out:
#       Undergraduate Major    Spread  Grad To Mid 90th Spread  \
# 0              Accounting  109800.0                 106000.0
# 1   Aerospace Engineering   96700.0                 103300.0
# 2             Agriculture  113700.0                 107400.0
# 3            Anthropology  104200.0                 101200.0
# 4            Architecture   85400.0                  94400.0
# 5             Art History   96200.0                  89200.0
# 6                 Biology   98100.0                  96200.0
# 7     Business Management  108200.0                 104000.0
# 8    Chemical Engineering  122100.0                 130800.0
# 9               Chemistry  102700.0                 105400.0
# 10      Civil Engineering   84600.0                  94100.0
# 11         Communications  105500.0                 104900.0
# 14           Construction  114700.0                 117300.0
# 15       Criminal Justice   74800.0                  72000.0
# ...

# %%
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Spread  Grad To Mid 90th Spread  \
# Group
# Business                   12      12                       12
# HASS                       22      22                       22
# STEM                       16      16                       16
#
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business                      12                        12
# HASS                          22                        22
# STEM                          16                        16
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                                 12                                 12
# HASS                                     22                                 22
# STEM                                     16                                 16
